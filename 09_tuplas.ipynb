# %% [markdown]
# ## TUPLAS

# %%
lista = [1, 3, 5, 7]
lista[0] = 2

print(lista)

# %%
tupla = (1, 3, 5, 7, 5, 5)
# tupla[0] = 9

# %%
tupla.count(5)

# %%
tupla.index(5)

# %%
tupla = ("maria", 1, 2, 0.5555, True, False)
print(tupla)
