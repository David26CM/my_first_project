# %% [markdown]
# ## LISTA
#
# - append -> inserta un elemento al final de la list
# - insert -> inserta un elemento en una posición dada
# - remove -> remueve un elemento de la lista
# - pop -> remueve el ultimo elemento
# - sort -> ordenaba la lista

# %%
list(range(6))

# %%
lista_numeros = [0,1, 2, 3, 4, 5]
lista_nombres = ["Juan", "Pedro", "Maria", "Ana"]
lista_mixta = [0, 0.1, "Marcos", "Maria"]

# %%
for item lista_mixta:
    print(item)

# %%
#remove
lista_nombres.remove("Pedro")
print(lista_nombres)
